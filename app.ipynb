# %%
# !pip install cohere faiss-cpu
# !pip install langchain
# !pip install --upgrade transformers huggingface_hub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transformers
#   Downloading transformers-4.44.0-py3-none-any.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.7 kB ? eta -:--:--
#      ---------------------------- ----------- 30.7/43.7 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------- 43.7/43.7 kB 428.4 kB/s eta 0:00:00
# Requirement already satisfied: huggingface_hub in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.24.5)
# Requirement already satisfied: filelock in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (6.0.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2024.7.24-cp312-cp312-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ----------------------------- ---------- 30.7/41.5 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------- 41.5/41.5 kB 505.0 kB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (2.32.2)
# Collecting safetensors>=0.4.1 (from transformers)
#   Downloading safetensors-0.4.4-cp312-none-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests->transformers) (2024.2.2)
# Downloading transformers-4.44.0-py3-none-any.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB 1.3 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/9.5 MB 871.5 kB/s eta 0:00:11
#     --------------------------------------- 0.1/9.5 MB 1.1 MB/s eta 0:00:09
#    - -------------------------------------- 0.3/9.5 MB 1.5 MB/s eta 0:00:06
#    - -------------------------------------- 0.4/9.5 MB 1.5 MB/s eta 0:00:07
#    -- ------------------------------------- 0.5/9.5 MB 1.7 MB/s eta 0:00:06
#    -- ------------------------------------- 0.7/9.5 MB 2.1 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/9.5 MB 2.5 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.2/9.5 MB 2.8 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.5 MB 3.3 MB/s eta 0:00:03
#    ------- -------------------------------- 1.8/9.5 MB 3.7 MB/s eta 0:00:03
#    --------- ------------------------------ 2.2/9.5 MB 4.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.6/9.5 MB 4.4 MB/s eta 0:00:02
#    ------------ --------------------------- 2.9/9.5 MB 4.5 MB/s eta 0:00:02
#    ------------- -------------------------- 3.3/9.5 MB 4.8 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.5 MB 4.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.0/9.5 MB 5.2 MB/s eta 0:00:02
#    ------------------ --------------------- 4.4/9.5 MB 5.3 MB/s eta 0:00:01
#    -------------------- ------------------- 4.9/9.5 MB 5.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.5 MB 5.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.6/9.5 MB 5.7 MB/s eta 0:00:01
#    ------------------------- -------------- 6.0/9.5 MB 5.9 MB/s eta 0:00:01
#    --------------------------- ------------ 6.4/9.5 MB 6.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.5 MB 6.1 MB/s eta 0:00:01
#    ------------------------------ --------- 7.1/9.5 MB 6.2 MB/s eta 0:00:01
#    ------------------------------- -------- 7.5/9.5 MB 6.3 MB/s eta 0:00:01
#    --------------------------------- ------ 7.8/9.5 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.2/9.5 MB 6.3 MB/s eta 0:00:01
#    ------------------------------------ --- 8.5/9.5 MB 6.3 MB/s eta 0:00:01
#    ------------------------------------- -- 8.8/9.5 MB 6.3 MB/s eta 0:00:01
#    ------------------------------------- -- 8.9/9.5 MB 6.2 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.5 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.5 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.5 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  9.5/9.5 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 5.6 MB/s eta 0:00:00
# Downloading regex-2024.7.24-cp312-cp312-win_amd64.whl (269 kB)
#    ---------------------------------------- 0.0/269.2 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/269.2 kB 660.6 kB/s eta 0:00:01
#    ----- --------------------------------- 41.0/269.2 kB 326.8 kB/s eta 0:00:01
#    ------------- ------------------------- 92.2/269.2 kB 585.1 kB/s eta 0:00:01
#    ---------------------------- ----------- 194.6/269.2 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 269.2/269.2 kB 1.2 MB/s eta 0:00:00
# Downloading safetensors-0.4.4-cp312-none-win_amd64.whl (286 kB)
#    ---------------------------------------- 0.0/286.3 kB ? eta -:--:--
#    ---- ----------------------------------- 30.7/286.3 kB 1.3 MB/s eta 0:00:01
#    ----------- --------------------------- 81.9/286.3 kB 919.0 kB/s eta 0:00:01
#    ----------- --------------------------- 81.9/286.3 kB 919.0 kB/s eta 0:00:01
#    ------------------------ --------------- 174.1/286.3 kB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 276.5/286.3 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 286.3/286.3 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: safetensors, regex, transformers
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\User\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python312\\site-packages\\transformers\\models\\deprecated\\trajectory_transformer\\convert_trajectory_transformer_original_pytorch_checkpoint_to_pytorch.py'
# HINT: This error might have occurred since this system does not have Windows Long Path support enabled. You can find information on how to enable this at https://pip.pypa.io/warnings/enable-long-paths
#
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# import json
# import torch
# import faiss
# import numpy as np
# from transformers import AutoTokenizer, BertModel
# print("fff")
# # הגדרת המודל והטוקנייזר של heBERT
# model_name = "avichr/heBERT"
# tokenizer = AutoTokenizer.from_pretrained(model_name)
# model = BertModel.from_pretrained(model_name)

# # פונקציה ליצירת embeddings לשאלה נתונה
# def get_embedding(question):
#     inputs = tokenizer(question, return_tensors="pt", padding=True, truncation=True)
#     with torch.no_grad():
#         outputs = model(**inputs)
#     # אנו לוקחים את הממוצע של כל ה-embeddings של הטוקנים
#     return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()
# Out:
# fff
# Some weights of BertModel were not initialized from the model checkpoint at avichr/heBERT and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import json
# import torch
import faiss
import numpy as np
from transformers import AutoTokenizer, BertModel

# # הגדרת המודל והטוקנייזר של heBERT
model_name = "avichr/heBERT"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 5
#       3 import faiss
#       4 import numpy as np
# ----> 5 from transformers import AutoTokenizer, BertModel
#       7 # # הגדרת המודל והטוקנייזר של heBERT
#       8 model_name = "avichr/heBERT"
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\transformers\__init__.py:26
#      23 from typing import TYPE_CHECKING
#      25 # Check the dependencies satisfy the minimal versions required.
# ---> 26 from . import dependency_versions_check
#      27 from .utils import (
#      28     OptionalDependencyNotAvailable,
#      29     _LazyModule,
#    (...)
#      48     logging,
#      49 )
#      52 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\transformers\dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)
#      37     "pyyaml",
#      38 ]
#
# ModuleNotFoundError: No module named 'transformers.utils'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !pip install --upgrade transformers huggingface_hub
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Collecting transformers
#   Downloading transformers-4.43.4-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 798.1 kB/s eta 0:00:00
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.23.5)
# Collecting huggingface_hub
#   Downloading huggingface_hub-0.24.5-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Downloading transformers-4.43.4-py3-none-any.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 28.7 MB/s eta 0:00:00
# Downloading huggingface_hub-0.24.5-py3-none-any.whl (417 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.5/417.5 kB 24.1 MB/s eta 0:00:00
# Installing collected packages: huggingface_hub, transformers
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.23.5
#     Uninstalling huggingface-hub-0.23.5:
#       Successfully uninstalled huggingface-hub-0.23.5
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.42.4
#     Uninstalling transformers-4.42.4:
#       Successfully uninstalled transformers-4.42.4
# Successfully installed huggingface_hub-0.24.5 transformers-4.43.4

# %%
from huggingface_hub import login

# הוסיפי את ה-Token שלך כאן
token = "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"
login(token=token)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer2 = AutoTokenizer.from_pretrained("yam-peleg/Hebrew-Mistral-7B")
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/4.33M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/552 [00:00<?, ?B/s]

# %%
# print("Model and tokenizer loaded successfully!")
# try:
#    model2 = AutoModelForCausalLM.from_pretrained("yam-peleg/Hebrew-Mistral-7B")
#    print("Model and tokenizer loaded successfully!")
# except Exception as e:
#     print(f"An error occurred: {e}")
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# בדיקת זמינות ה-GPU
device = "cuda" if torch.cuda.is_available() else "cpu"
print("GPU זמין ונמצא בשימוש" if device == "cuda" else "GPU לא זמין, משתמשים ב-CPU")

model_name = "yam-peleg/Hebrew-Mistral-7B"

# טעינת ה-tokenizer
tokenizer2 = AutoTokenizer.from_pretrained(model_name)

# טעינת המודל עם device_map אוטומטי
try:
    model2 = AutoModelForCausalLM.from_pretrained(
        model_name,
        torch_dtype=torch.float16 if device == "cuda" else torch.float32,
        device_map="auto" if device == "cuda" else None
    )
    print("המודל וה-tokenizer נטענו בהצלחה!")
except Exception as e:
    print(f"קרתה שגיאה: {e}")

# דוגמה לשימוש במודל
text = "התחל טקסט עברי כאן"
inputs = tokenizer2(text, return_tensors="pt").to(device)
outputs = model2.generate(inputs["input_ids"])

print("טקסט שנוצר:")
print(tokenizer2.decode(outputs[0], skip_special_tokens=True))
# Out:
# GPU זמין ונמצא בשימוש
# config.json:   0%|          | 0.00/674 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.60G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/524M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device device because they were offloaded to the cpu.
# המודל וה-tokenizer נטענו בהצלחה!
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token.As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1249: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# טקסט שנוצר:
# התחל טקסט עברי כאן או כאן או כאן או

# %%
# פונקציה ליצירת embeddingsYour session crashed after using all available RAM.
 #לשאלה נתונה
#הגדרת max_length: הוספתי את הפרמטר max_length=512 בקריאה ל-tokenizer כדי למנוע את הודעת האזהרה.
def get_embedding(question):
    inputs = tokenizer(question, return_tensors="pt", padding=True, truncation=True, max_length=512)
    with torch.no_grad():
        outputs = model(**inputs)
    # אנו לוקחים את הממוצע של כל ה-embeddings של הטוקנים
    return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()

# %%
def generate_token(question):
    # יצירת input_ids מהשאלה
    input_ids = tokenizer2(question, return_tensors="pt")

    # הפעלת המודל ליצירת טוקנים
    outputs = model2.generate(**input_ids, max_length=50)  # את יכולה לשנות את max_length לפי הצורך

    # פענוח והחזרת הטוקן שנוצר
    generated_text = tokenizer2.decode(outputs[0], skip_special_tokens=True)

    # פיצול הטקסט לטוקנים
    tokens = tokenizer2.tokenize(generated_text)

    return tokens

# בדיקת הפונקציה עם שאלה לדוגמה
question = "מה הדין לגבי שמירת שבת?"
tokens = generate_token(question)
print(tokens)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1797: UserWarning: You are calling .generate() with the `input_ids` being on a device type different than your model's device. `input_ids` is on cpu, whereas the model is on cuda. You may experience unexpected behaviors or slower generation. Please make sure that you have put `input_ids` to the correct device by calling for example input_ids = input_ids.to('cuda') before running `.generate()`.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-602efe49ef7e> in <cell line: 18>()
#      16 # בדיקת הפונקציה עם שאלה לדוגמה
#      17 question = "מה הדין לגבי שמירת שבת?"
# ---> 18 tokens = generate_token(question)
#      19 print(tokens)
#
# <ipython-input-13-602efe49ef7e> in generate_token(question)
#       4
#       5     # הפעלת המודל ליצירת טוקנים
# ----> 6     outputs = model2.generate(**input_ids, max_length=50)  # את יכולה לשנות את max_length לפי הצורך
#       7
#       8     # פענוח והחזרת הטוקן שנוצר
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1912
#    1913             # 13. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 1914             result = self._sample(
#    1915                 input_ids,
#    1916                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, logits_warper, **model_kwargs)
#    2649
#    2650             # forward pass to get next token
# -> 2651             outputs = self(
#    2652                 **model_inputs,
#    2653                 return_dict=True,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     167                 output = module._old_forward(*args, **kwargs)
#     168         else:
# --> 169             output = module._old_forward(*args, **kwargs)
#     170         return module._hf_hook.post_forward(module, output)
#     171
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1198
#    1199         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1200         outputs = self.model(
#    1201             input_ids=input_ids,
#    1202             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     974                 )
#     975             else:
# --> 976                 layer_outputs = decoder_layer(
#     977                     hidden_states,
#     978                     attention_mask=causal_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     167                 output = module._old_forward(*args, **kwargs)
#     168         else:
# --> 169             output = module._old_forward(*args, **kwargs)
#     170         return module._hf_hook.post_forward(module, output)
#     171
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, **kwargs)
#     730         residual = hidden_states
#     731         hidden_states = self.post_attention_layernorm(hidden_states)
# --> 732         hidden_states = self.mlp(hidden_states)
#     733         hidden_states = residual + hidden_states
#     734
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     167                 output = module._old_forward(*args, **kwargs)
#     168         else:
# --> 169             output = module._old_forward(*args, **kwargs)
#     170         return module._hf_hook.post_forward(module, output)
#     171
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, hidden_state)
#     169
#     170     def forward(self, hidden_state):
# --> 171         return self.down_proj(self.act_fn(self.gate_proj(hidden_state)) * self.up_proj(hidden_state))
#     172
#     173
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     162
#     163     def new_forward(module, *args, **kwargs):
# --> 164         args, kwargs = module._hf_hook.pre_forward(module, *args, **kwargs)
#     165         if module._hf_hook.no_grad:
#     166             with torch.no_grad():
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in pre_forward(self, module, *args, **kwargs)
#     333             ):
#     334                 fp16_statistics = None
# --> 335                 value = self.weights_map[name]
#     336                 if "weight" in name and name.replace("weight", "SCB") in self.weights_map.keys():
#     337                     if value.dtype == torch.int8:
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/offload.py in __getitem__(self, key)
#     116
#     117     def __getitem__(self, key):
# --> 118         return self.dataset[f"{self.prefix}{key}"]
#     119
#     120     def __iter__(self):
#
# /usr/local/lib/python3.10/dist-packages/accelerate/utils/offload.py in __getitem__(self, key)
#     169             try:
#     170                 with safe_open(weight_info["safetensors_file"], framework="pt", device=device) as f:
# --> 171                     tensor = f.get_tensor(weight_info.get("weight_name", key))
#     172             except TypeError:
#     173                 # if failed to get_tensor on the device, such as bf16 on mps, try to load it on CPU first
#
# KeyboardInterrupt:

# %%
def get_embedding2(question):
    print(question)
    # המרת הטקסט ל-input_ids
    inputs = tokenizer2(text, return_tensors="pt", padding=True, truncation=True)

    # הפעלת המודל להפקת embeddings
    with torch.no_grad():
        outputs = model2(**inputs, output_hidden_states=True)

    # קבלת hidden states של כל הטוקנים
    hidden_states = outputs.hidden_states[-1]  # בוחרים את השכבה האחרונה

    # חישוב הממוצע של ה-embeddings של כל הטוקנים
    embeddings = hidden_states.mean(dim=1).squeeze().numpy()

    return embeddings

# בדיקת הפונקציה עם טקסט לדוגמה
input_text = "שלום! מה שלומך היום?"
embedding = get_embedding2(input_text)
print(embedding)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# שלום! מה שלומך היום?
# [ 2.812   0.0607 -1.676  ... -1.807   2.26   -0.284 ]

# %%
def get_embedding3(question):
    print(question)
    # המרת הטקסט ל-input_ids
    inputs = tokenizer2(question, return_tensors="pt", padding=True, truncation=True).to("cuda" if torch.cuda.is_available() else "cpu")

    # הפעלת המודל להפקת embeddings
    with torch.no_grad():
        outputs = model2(**inputs, output_hidden_states=True)

    # קבלת hidden states של כל הטוקנים
    hidden_states = outputs.hidden_states[-1]  # בוחרים את השכבה האחרונה

    # חישוב הממוצע של ה-embeddings של כל הטוקנים
    embeddings = hidden_states.mean(dim=1).squeeze().cpu().numpy()

    return embeddings

# בדיקת הפונקציה עם טקסט לדוגמה
input_text = "שלום! מה שלומך היום?"
embedding = get_embedding3(input_text)
print(embedding)

# %%
import numpy as np
#from google.colab import drive
#drive.mount('/content/drive')
# קריאת הקובץ JSON
with open('/content/sample_data/פרי גני שוע.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# שליפת כל השאלות מהקובץ
questions = []
for book in data['contain'].values():
    for chapter in book.values():
        for verse in chapter.values():
            for qa in verse:
                questions.append(qa['question'])

# המרת כל השאלות ל-embeddings
# embeddings = np.array([get_embedding(question) for question in questions])
# import pickle

# # שמירה
# with open('/content/sample_data/embeddings.pkl', 'wb') as f:
#     pickle.dump(embeddings, f)
# print(len(questions))
# embeddings2 = np.array([get_embedding2(question) for question in questions])
# # with open('/content/sample_data/embeddings2.pkl', 'wb') as f:
# #     pickle.dump(embeddings2, f)
# print("cancel")

# %%
# חישוב embeddings עבור כל השאלות הראשונות
embeddings2 = np.array([get_embedding2(question) for question in questions])
# Out:
# Streaming output truncated to the last 5000 lines.
# יב. אכל חצי זית ושתה חצי זית?
# יג. האכל דבר כבריתו?
# יד. אכל עוגה שאין במזונות שיעור קמח לברכה אחת מעין שלוש?
# טו. עד אימתי יכול לברך ברכה אחרונה?
# 1. מדוע צריך ליטול ידיו לסעודת פת?
# 2. האם צריך ליטול ידיו לאכילת פירות?
# 1. האם רשאי ליטול מכלי שפיו צר?
# 2. האם רשאי ליטול ידיו לחצאין?
# 1. שפך מים על ידו האחת ושפשפה בחברתה?
# 2. נטל ידיו ברביעית או במים שניים ובא אחר ונגע בידיו קודם שנגבן?
# 3. האם צריך שאוזן הכלי שנטל יהיה נגוב?
# 4. מדוע השופך רביעית כאחד אין צריך מים שניים לטהרם?
# 5. נטל ידיו ברביעית ונגע אחר בידיו וברך על נטילת ידיים ואח"כ נזכר?
# 1. ארבעה שהניחו ידיהם זה בצד זה ונטלו כאחת, ושפשפו ידיהם זה בזה?
# 1. נטל ידו אחת שתי פעמים וידו השניה פעם אחת ונגעה בה?
# 1. נטל שתי ידיו ברביעית בבת אחת ונגע חוץ למקום שנפלו המים?
# 1. נטל ידו אחת בפחות מרביעית ושפשף בשערות ראשו?
# 2. מדוע צריכים מים שניים, שיקנח ידיו במגבת?
# 1. נטל ידיו במים ראשונים והיה על ידו קיסם?
# 1. מי שיש לו רטיה על מכה שבידו?
# 2. האם רשאי ליטול מים ראשונים ע"ג קרקע?
# 1. מתי מותר לאכול בלא נטילת ידיים רק בכריכת ידו במפה?
# 2. מי שאין לו במה לכסות ידיו ואין לו מים?
# 3. שומרי גינות ופרדסים, מה דינם?
# 4. היושב בביתו עד כמה צריך לטרוח אחר מים?
# 1. המאכיל לאחרים האם צריך ליטול ידיו?
# 2. האוכל במזלג האם צריך נטילה?
# 3. מהו להאכיל למי שלא נטל ידיו?
# 1. האם יכול ליטול ידיו שחרית עבור על מה שיאכל כל היום?
# 2. באיזה מקרה מהני נטילת שחרית לכל היום אפילו הסיח דעתו מהם?
# 3. נטל ידיו שחרית ושמרן בבתי ידיים והגיע למקום מים?
# 4. האם מהני להתנות על הידיים גם בנוטל ידיו לאכילה?
# 1. מי שעומד באמצע הסעודה ונגע במקומות המכוסים או שחכך בראשו?
# 2. נגע במקומות המכוסים בעוד הפרוסה בפיו?
# 3. נגע בטומאה באמצע האכילה?
# 1. העושה צרכיו ורוצה לאכול?
# 1. רבים מסובים בסעודה מי נוטל ראשון?
# 2. הפסיק הרבה בין נטילה לבציעה?
# 1. היכן יש לבצוע את הפת?
# 2. כיצד יחתוך את פרוסת הבציעה?
# 3. מהו שיעור החיתוך בפת קודם הברכה?
# 4. מהו גודל הפרוסה שיבצע?
# 5. כיצד יבצע בשבת ויו"ט?
# 6. המוציא אחרים ידי חובתן בברכת המוציא?
# 1. כיצד מברך ברכת המוציא?
# 2. כיצד מוציא אחרים בברכתו?
# 3. אנחנו טוחנים ולשים ואופים הלחם ואמאי מייחסים זאת לשם?
# 1. מתי יש לברך את ברכת המוציא?
# 2. כיצד אוחז את הפת בשעת הברכה?
# 3. מהם עשר המצוות התלויות בפת?
# 1. באיזה פת לא בעינן מלח?
# 2. מדוע יש מצווה להביא מלח על השולחן קודם הבציעה?
# 1. שח בין ברכה לאכילה?
# 2. עבר ושח בעודו לועס?
# 3. מהו לאכול ולשתות קודם בהמתו?
# 4. המוציא אחרים בברכתו ושחו קודם שאכלו?
# 5. שח המברך קודם שטעם והשומעים לא שחו כלל?
# 1. ראובן שהיה נוטל ידיו לאכילה ויעקב בירך המוציא ונתכוון להוציאו ואח"כ ניגב ידיו ובירך על נטילתו?
# 2. נטל ידיו ונגבן וברך המוציא ושכח לברך על נטילת ידים?
# 1. שכח ואכל ולא ברך המוציא?
# 1. מסופק אם ברך המוציא?
# 1. במקום המוציא ברך שהכל נהיה בדברו?
# 1. מתי אמרינן דעדיף שאחד יברך ויוציא את כולם?
# 2. מהי הסבה?
# 3. מדוע עדיף שאחד יברך לכולם ולא שכל אחד יברך לעצמו?
# 4. מתי מהני שאחד יוציא את כולם אף בלא הסבה?
# 1. האם ברכיבה על בהמות יכול אחד להוציא את כולם?
# 2. ישבו בעגלה הנוסעת או בספינה או במטוס באויר?
# 3. מדוע השמש יוצא בברכת המוציא והרי אינו קבוע אצל השולחן?
# 4. האוכלים בשדה בשעה אחת ומככר אחד מפוזרים ומפורדים?
# 1. האוכלים בשדה מפוזרים ולא קבעו מקום ובירך אחד בשביל להוציא את כלם?
# 1. מי מברך המוציא להוציא את האחרים?
# 2. כהן עם הארץ ויש שם ת"ח?
# 3. ת"ח גדול וכהן ת"ח שהוא פחות ממנו?
# 4. בעל הסעודה ות"ח גדול?
# 5. מדוע המברך צריך לומר תחילה ברשות מורי ורבותי?
# 6. כשיש כהן שצריך להקדימו ויש אחר הרוצה לבצוע?
# 1. האם רשאים המסובים לטעום קודם שיטעם הבוצע?
# 2. לכל אחד היה ככר בפני עצמו האם רשאים להקדים לבוצע?
# 1. אמאי אין הבוצע רשאי לבצוע עד שיכלה אמן מפי רוב העונים?
# 1. מי פושט ידו תחילה לקערת האכל?
# 1. כיצד על הבוצע לחלק הפרוסות לפני המסובים?
# 1. מי שאינו אוכל מהו שיברך המוציא להוציא האחרים?
# 2. מתי רשאי לברך אע"פ שאינו אוכל עמהם?
# 1. בשבת מהו שיברך לו חבירו שאינו אוכל עמו ברכת המוציא?
# 2. מתי יכול לברך לאחרים אע"פ שאינו אוכל עמהם ומוציא אותם חובת ברכת המוציא?
# 3. מדוע עליו לאכול את פרוסת המוציא קודם שיאכל פרוסה נוספת?
# 4. מהו להאכיל מפרוסות המוציא לכותי עוף או בהמה?
# 1. היו לפניו חתיכות של פת ופת שלם ממין אחד על איזה יברך?
# 2. השלם משעורים והחתיכות מחטים?
# 3. השלם משיפון והפרוסה מחטים?
# 1. שתי הככרות שלמות וממין אחד?
# 2. יש לו שני חצאי לחם ואין לו לחם שלם?
# 1. שתי ככרות שנדבקו באפיה?
# 1. פת שעורין ופת כוסמין על איזה יברך?
# 2. כוסמין ושיפון איזה עדיף?
# 3. מהו הכלל בקדימה בברכת הפת?
# 1. פת עכו"ם נקיה ופת קיבר של ישראל?
# 2. בעל הבית שאינו נזהר מפת עכו"ם ורוצה לאכול הנקיה ומוציא בני ביתו הנזהרים ואוכלים פת קיבר של ישראל?
# 3. בעל הבית הנזהר בפת עכו"ם ויש לו אורח שאינו נזהר ורוצה לאכול פת נקיה של עכו"ם?
# 1. מהי פת הבאה בכיסנין?
# 1. חברים שישבו לאכול פת ויצאו לקראת חתן או לקראת כלה או לדבר הרשות?
# 2. האם מהני להניח חברים כשהיו מסובין לשתות או לאכול פרות?
# 3. במאי חמור שינוי מקום מהסח הדעת לדעת מרן?
# 4. במאי פליג הרמ"א על השו"ע?
# 5. אכל פחות מכזית פת ויצא לחוץ?
# 6. הסיח דעתו מאכילה ויצא לחוץ?
# 7. מי שאכל במקום אחד ויצא למקום אחר ורוצה להמשיך לאכול שם והניח חברים במקומו?
# 8. האם יכול לעקור לכתחילה ממקומו על מנת לחזור?
# 9. מי שמזמינים אותו באמצע אכילתו לאכול במקום אחר?
# 10. האם בסעודת פירות דינא הכי?
# 1. הנמצא בתוך פרדס ורוצה לאכול מפירות כל האילנות?
# 2. שני פרדסים הסמוכים זה לזה וברך על הראשון?
# 3. מי שברך על פרי לאכול כאן, ולא אכל ממנו עד שהגיע לחדר השני?
# 1. מתי מודה השו"ע לעוקר שולחנו בסעודת פת מבית לבית שמברך ברכה אחרונה על הכל במקום השני?
# 2. מהו לאכול סעודה בדרך הליכתו?
# 3. התחיל לאכול בבית והלך לדרכו?
# 1. האם שבעת המינים טעונים ברכה לאחריהם במקומם?
# 1. המתפלל באמצע סעודתו האם הוי הפסק?
# 1. אדם שישן בסעודתו האם הוי הפסק?
# 2. הפסיק לנקביו באמצע הסעודה?
# 1. גמר סעודתו ונטל מים אחרונים?
# 2. אמר הב לן ונברך?
# 1. הסומך על שולחן אחרים ואמר הב לן ונברך?
# 2. הסומך על שולחן אחרים ונטל מים אחרונים?
# 1. נטל הכוס לברך?
# 1. הנכנס לבית חבירו ויש שם הרבה חבורות שאוכלים וכל אחד מושיט לו כוס?
# 1. הקרואים בבית בעל הבית לאכול פרות?
# 1. מי צריך לדאוג מריח הפה?
# 2. מדוע אסור לאכול מלח באגודלו אחר אכילתו?
# 1. מדוע אין להסיר המפה והלחם עד אחר ברכת המזון?
# 1. מי שאינו משייר פת על שולחנו?
# 2. מהו להסיר הפתיתים קודם ברכת המזון?
# 1. האם צריך לכבד הבית קודם נטילת מים אחרונים?
# 2. הנוטל ידיו על פרורים שאין בהם כזית?
# 1. הדורס על פרורים שאין בהם כזית?
# 1. מדוע נוהגים לכסות הסכין בברכת המזון?
# 2. בשבת ויו"ט כיצד נוהגים בזה?
# 1. מדוע חייבים ליטול מים אחרונים?
# 2. מי שיש לו מים מצומצמים?
# 1. מהו ליטול מים אחרונים ע"ג קרקע?
# 2. במקום שאין כלי ליטלם לתוכו?
# 1. באיזה חום של המים אין ליטול?
# 1. עד היכן צריך ליטול מים אחרונים?
# 1. כיצד עליו ליטול על אצבעותיו?
# 1. אם המסובין רבים מהו סדר הנטילה?
# 2. מה הטעם שהמברך נוטל ראשון מבין החמשה?
# 1. האם מברכים על מים אחרונים?
# 1. האם מים אחרונים צריכים ניגוב?
# 2. מהו שיעור מים אחרונים?
# 1. מה טעם היש נוהגים לא ליטול כלל מים אחרונים?
# 1. האם ברכת המזון טעונה כוס?
# 2. מדוע צריך כוס לברכת המזון?
# 1. אנדרוגינוס וטומטום מהם בזמון?
# 1. באיזה גיל קטן מצטרף לזמון?
# 2. חרש ושוטה לענין זמון?
# 1. מי שנידוהו על עברה?
# 1. מתי האחד מפסיק על כרחו לשניים?
# 2. זימן האחד על השנים על כרחם?
# 1. עד היכן צריך להפסיק בברכת הזמון?
# 2. מי ששמע זמון ורוצה להמשיך לאכול ולמעשה לא אכל מהיכן יברך ברכת המזון?
# 3. אחד שהפסיק לזמון לשנים מהו שיפסיק לשנים אחרים?
# 4. בזמון בעשרה כמה מהם צריכים להפסיק כדי להשלים? ועד היכן מפסיקים?
# 1. את מי יש לכבד בזימון ובברכת המזון?
# 2. אם הגדול בחכמה מוציא שיעול?
# 3. מהי ברכת בעל הבית? ומי מברך אותה?
# 1. האם צריך להקדים כהן לישראל בסעודה?
# 1. מי שנותנים לו לברך ואינו מברך?
# 1. מדוע צריך לחזר אחר כוס של ברכה?
# 2. האם צריך כל אחד מבני הבית לברך ברכת הרחמן? והאם גם את היהי רצון?
# 1. מדוע לא מברכים על פרות האילן בורא פרי האדמה הרי גידולם מן הארץ?
# 2. פרי שראוי לחוש שהתליע?
# 3. הרוצה לקלוף הפרי ולאוכלו?
# 4. מדוע אין לברך על משקה או מאכל שהוא חם או קר ביותר?
# 5. ברך על מאכל ולאחר שאכל מעט נמאס בעיניו?
# 6. מדוע קבעו ליין ברכה בפני עצמה?
# 7. יין שערבב עם דבש ופלפלין מתי איבד ברכתו?
# 8. נתערב יין בשכר?
# 1. מה מברכים על הבוסר?
# 2. מדוע יזהר שלא יאכל מן הבוסר שיעור שחייב בברכה אחרונה?
# 3. מה הדין בשאר האילנות?
# 4. במה חולק הגר"א על פסק השו"ע?
# 1. מה מברכים על גרעיני הפירות?
# 2. גרעינים המרים שאינם ראויים לאכילה אפילו ע"י הדחק?
# 1. השותה שמן זית מאי מברך?
# 2. החושש בגרונו ושותה שמן עם פת מה מברך?
# 3. המערב השמן עם שאר משקה לרפואה?
# 4. השותה שמן זית המעורב במשקה שלא לרפואה אלא למאכל?
# 1. שקדים המרים מה מברכים עליהם?
# 1. מה מברכים על הצלף?
# 2. קליפת התפוז שטיגנה בדבש?
# 1. תמרים שהוציא גרעיניהם ומעכן בידו?
# 2. ריבת פרות מה מברך עליה?
# 3. חצילים מרוסקים מהי ברכתם?
# 1. דבש הזב מתמרים?
# 1. נובלות שהן תמרים שאין מתבשלים על האילן?
# 1. מה מברכים על המים שהפירות בושלו בהם?
# 2. פרות שרוב אכילתן ע"י בישול?
# 1. השותה רוטב של פירות שבעת המינים שבושלו?
# 2. מה מברך על מי שריית צימוקים?
# 3. מה התנאי שהמים היוצאים מהצימוקים ששראן במים יהיה להם דין יין?
# 1. פרות הנאכלים בין חיים ובין מבושלים?
# 2. פירות שהדרך לאוכלם רק מבושלים?
# 3. פירות שהדרך לאכלם רק חיים?
# 4. בישל רמונים מה מברך תחילה וסוף?
# 1. אגוז המטוגן בדבש?
# 2. אגוזים שחוקים שטיגנם בדבש?
# 1. שקדים רכים ומרים בקליפתם הירוקה וטיגנם בדבש?
# 2. פרי גמור שאינו ראוי לאכילה חי וטיגנו בדבש?
# 1. המוצץ קנה סוכר?
# 2. מה מברכים על הסוכר?
# 1. האוכל פלפל וזנגביל וצפורן יבשים?
# 1. הנותן אגוז לתוך שכר כדי לעצור השלשול?
# 2. האוכל מקלות קנמון?
# 1. האוכל פלפל וזנגביל רטובים?
# 2. המסופק אם הוא עקר הפרי או לא?
# 1. מה מברכים על פטל ותות סנה ובננות?
# 2. מה החילוק בין צמח שמברכים על פריו פרי העץ לבין צמח שמברכים על פריו פרי האדמה?
# 3. מה מברכים על אוכמניות?
# 4. פירות שמוצצים המשקה וזורקים הקליפה?
# 5. פרות שמוציאים אילני סרק?
# 6. אילנות סרק הגדלים ע"י נטיעה?
# 7. ענבי ההדס מה מברכים עליהם?
# 1. זנגביל שמרקחים אותו כדבש?
# 1. בשמים שחוקים המעורבים בסוכר?
# 2. נוכרי שעשה מרקחת דבש עם הבשמים?
# 1. מה הרבותא דמברכים בורא פרי האדמה על צנון?
# 1. מה מברכים על דבר שאין גידולו מן הארץ?
# 2. שרביטים של קטניות?
# 3. חומץ יין שערבו במים עד שראוי לשתיה?
# 4. מדוע אין מברכים בורא מיני מזונות על מי שעורים מבושלים?
# 1. ריחו חומץ וטעמו יין?
# 2. התחיל גם טעמו להחמיץ?
# 1. השותה שמרי יין עצמם בלא מים?
# 2. נתן מים בשמרי היין?
# 3. יין ששפך עליו מים?
# 4. מה החילוק בין יין שלנו ליין שבזמן חז"ל כשנותן מים בשמרים?
# 5. מה דין היין לדעת השו"ע? ויינות שבזמננו?
# 6. האם מיץ ענבים שוה דינו למזיגת יין?
# 7. מה דין מיץ ענבים משוחזר?
# 1. מהו תמד ומה דינו?
# 2. האם חרצנים של צמוקים דינם כחרצנים של ענבים?
# 3. זגים שנתנו עליהם תאנים או שאר פרות לחזק כח היין הנשאר בהם?
# 1. השותה מים שלא לרוות צמאונו?
# 2. השותה מים או שאר משקים להעביר האומצא שעמדה בגרונו?
# 1. אכלים ומשקים שאדם אוכל ושותה לרפואה?
# 2. אנסוהו לשתות או לאכול?
# 3. אכל איסור מפני הסכנה מדוע מברך הרי הוי אנוס?
# 4. אכל מפני הסכנה דבר שנפשו קצה בזה?
# 1. דבש דבורים מה מברכים עליו?
# 1. ורדים ומיני פרות שמרקחים בדבש?
# 2. מרקחת שהיא לרפואה?
# 1. מהו הכלל בעיקר וטפל ומה נחשב לעיקר ומה לטפל?
# 2. מיני מתיקה שנותנים בהם קמח כדי לדבק?
# 1. כל דבר שהוא מסופק בברכתו?
# 1. ירקות הנאכלים בין חיים ובין מבושלים?
# 2. סלקא וקרא וכרוב?
# 3. האוכל חסה עם בשר?
# 4. שומים ובצלים?
# 5. טיגן בצלים בשמן או חמאה?
# 1. מה מברכים על המים שבשלו בהם הירקות?
# 2. לביבות שבשלן במים ורוצה לשתות רק המים?
# 3. שרה ירקות במים?
# 4. בישל ירקות עם בשר?
# 1. ירקות שסחט את מימיהם?
# 1. שומשומין שטחנן?
# 2. הלפת והגזר?
# 5. ברכת הריח וברכת אכילה ושתיה איזה יקדים?
# 1. מהו כלל העקר בטפל?
# 2. היו שניהם עקרים?
# 3. חמשת מיני דגן המעורבים עם שאר מינים?
# 4. האוכל דג מליח ופת עמו?
# 5. לא היה הטפל לפניו בשעה שברך על העקר?
# 6. היה הטפל חביב עליו?
# 7. באיזה מקרים לא שיך לומר דטפל כלל?
# 8. מדוע טוב להימנע מלאכול פת למיתוק שתיית היין שרף?
# 9. השורה אחר גמר אכילתו מעט פת ביין שרף כדי לעכל המאכל?
# 10. מתי יברך אף על הטפל?
# 1. מרקחת שמניחים על רקיקים דקים?
# 2. גלידה בגביע וגלידת קאסטה?
# 3. קאבוקים - בוטן אמריקאי?
# 4. חטיף שוקולד מצופה ובו וופל פריך שאחד ממרכיביו קמח?
# 1. מה החילוק בין פת ויין לשאר אכלין ומשקין לענין שהאחד יוציא את חבירו בברכתו?
# 2. כיצד נקטינן האידנא?
# 3. האם גם בברכה אחרונה אחד מוציא את כלם בשאר מינים?
# 4. מהי דעת הרמ"א בזה?
# 1. המוציא את האחרים האם צריך שיאכל וישתה עמהם?
# 2. ברך להוציא האחרים ואינו אוכל עמהם?
# 3. ברך להוציא אחרים ולא ענו אמן?
# 1. מי שלא שמע את כל הברכה מהמברך האם יצא?
# 2. מתי אמרינן דהמשנה ממטבע שטבעו חכמים לא יצא?
# 1. מתי שם ומלכות אינו מעכב בברכה ומתי מעכב?
# 2. מדוע בתפילת שמונה עשרה לא תקנו מלכות?
# 3. דילג שם או מלכות?
# 4. דילג תיבת העולם לבדו?
# 1. העונה אמן אחר ברכותיו?
# 2. השומע ישראל המברך ושמע רק סוף הברכה?
# 3. השומע תינוק המברך האם צריך לענות אמן?
# 4. השומע ברכה מגוי או מיהודי שהמיר דתו לעבודת גלולים?
# 5. גדול הלומד את הברכות מן הגמ' האם יכול להזכיר השם?
# 6. תינוק שלא הגיע לחינוך מהו לענות אמן על ברכותיו?
# 1. המברך ברכה שלא לצורך כלל?
# 2. כיצד יתכן לגרום לברכה שאינה צריכה?
# 3. מדוע אסור להוציא שם שמים לבטלה בלא ברכה?
# 4. השומע את חברו מזכיר שם השם לקלל את חברו?
# 5. ברך על מוקצה בשוגג ולעסו בפיו האם רשאי לבולעו?
# 6. מי שנתספק אם ברך או לא?
# 1. האם יש חילוק בין בשמים תלושים לבשמים מחוברים?
# 2. שכח והריח בלא ברכה?
# 3. האם מברכים ברכה אחרונה על הריח?
# 4. מי שאינו מריח מהו שיוציא אחר בברכתו?
# 5. היו לפניו שתי ברכות אחת של טעם ואחרת של ריח?
# 1. ברכת עצי בשמים ועשבי בשמים על מה קאי?
# 2. דבר שהוא לא מין עץ ולא מין עשב?
# 3. פרי הראוי לאכילה ונותן ריח טוב?
# 4. דבר האסור באכילה מהו להריח בו?
# 5. המברך שהכל על הריח?
# 6. קנמון וצפורן שרוצה להריח בהם מה מברך?
# 1. ורד ומי ורד?
# 2. לבונה ומצטיכי?
# 1. על מה מברך בורא שמן ערב?
# 1. פרות עץ שכתשן וטחנן וריח נודף מהם?
# 1. המברך ברכת הגומל על חברו?
# 2. קיי"ל דשומע כעונה גם בלי שיענה אמן, ואמאי חייב הכא לענות אמן?
# 3. מהו שהאיש יברך הגומל בשביל אשתו היולדת?
# 1. המברך ברכת הגומל לעצמו ונתכון לפטור את חבירו?
# 2. עד כמה יכול לאחר ברכת הגומל?
# 1. ההולך מעיר לעיר האם מברך ברכת הגומל?
# 2. מדוע בפחות מפרסה אין לברך?
# 3. הטסים באוירון?
# 1. על איזה חולי צריך לברך ברכת הגומל?
# 2. חולי שיש בו חום מתי יברך לרמ"א?
# 1. חוץ מן הארבעה הנ"ל מי צריך לברך הגומל?
# 2. מי שנסע בעיר וניצול מתאונת דרכים קטלנית?
# 1. מהו הטבת חלום?
# 2. מי שחלם חלום קשה על חבירו?
# 1. מתי יש לברך על הגשמים?
# 2. מה מברך?
# 1. מה מברך על שמועות?
# 2. האם מכל אדם ששומע השמועה יכול לברך?
# 3. שמע שנתפס הגזלן שגזל ממנו האם מברך?
# 4. מי שנאלץ לישא עשירה מחמת עניותו?
# 5. נודע לו שהחמיץ יינו?
# 6. מדוע תבע יצחק יסורין?
# 7. מצא מציאה וירא שמא ישמע למלך ויקח כל אשר לו?
# 1. ילדה אשתו מה מברך?
# 2. מתה אשתו בלדתה?
# 1. האם צריך לברך ברכת דיין האמת בשם ומלכות?
# 2. מת אביו וירשו ממון?
# 1. קהל שבנו בית כנסת?
# 2. סתר ביתו ובנאו מחדש?
# 3. קנה ספר חדש?
# 4. קנה כלים ישנים שלא היה לו מעולם?
# 1. קנה בגד חדש מתי עליו לברך?
# 2. באיזה מקרה אין לברך בשעת הקניה?
# 3. חליפה שקונים לנער בר מצוה מתי יברך שהחיינו?
# 4. כלים שצריכים טבילה ובית חדש מתי יברך?
# 1. קנה כלים שמשתמשים בהם הוא ובני ביתו?
# 2. המקבל מתנה?
# 1. חלוק ומנעלים ואנפילאות?
# 2. הלובש בגד חדש מה נוהגים לומר לו?
# 1. הרואה עבודה זרה מה יברך?
# 2. הרואה מקום שנעקרה ממנו עבודה זרה?
# 3. הרואה בבל הרשעה?
# 4. הרואה ששים רבוא מישראל ביחד?
# 5. הרואה חכמי ישראל? ומלכי ישראל?
# 6. הרואה קברי ישראל?
# 1. הרואה את חבירו לאחר ל' יום? ולאחר י"ב חודש?
# 2. מי שלא ראה את חבירו מעולם ושלח לו מכתבים?
# 3. מי שנעשה בנו בר מצוה מה מברך?
# 4. מה פירוש הברכה שפטרני מענשו של זה?
# 1. הרואה פרי חדש המתחדש משנה לשנה?
# 2. מתי יברך קדם אכילה או לאחריה?
# 3. האם ברכת שהחיינו על הפרי היא חובה?
# 4. האם מברכים שהחיינו על הבוסר?
# 5. מי שלא ברך בשעת אכילה ראשונה?
# 1. שני מיני תאנים או תפוחים או אגסים או ענבים?
# 2. ברך שהחיינו על ענבים האם צריך לברך גם על המיץ החדש?
# 3. האם מברכים שהחיינו על אתרוג?
# 4. פרי שמתחדש פעמים בשנה? על ריח?
# 5. על מי מברכים משנה הבריות?
# 6. הרואה בריות נאות ואילנות טובות?
# הזיז הנ"ל ואין בו ד' על ד'?
# שני זיזים זה למטה מזה והם של שני אנשים?
# היו הזיזים של אדם אחד?
# אין בשני הזיזים ד' על ד'?
# היה בזיז התחתון ד' על ד' ובעליון אין בו ארבעה?
# באיזה כלים מותר להשתמש על הזיז?
# באיזה כלים מותר להשתמש על הגג שהוא ד' על ד'?
# זיז היוצא לאויר הכרמלית?
# בור ברה"ר וחוליא סביבו מהו למלאת ממנו לרה"י?
# היה הבור רחוק ארבעה טפחים מרה"י?
# האם צריך שגם החלון ששואב ממנו יהא גבוה עשרה טפחים מן הקרקע?
# העומד ברה"ר ומשלשל דלי בחבל לתוך בור עמוק ד' ורחב ד' וממלא מים ומוציא לרה"ר?
# בור וחלון העומדים בדיוטא אחת מהו להוריד הדלי מן החלון אל הבור?
# אשפה שהיא בר"ה וגבוה עשרה ורחבה ארבעה האם מותר לזרוק לה מרה"י?
# האשפה מופלגת מן החלון ארבעה טפחים מהו לזרוק לשם?
# האם בעינן ערוב בין הבתים לאשפה?
# האם צריך לחוש שמא יתגלגל מן האשפה לרה"ר ואתי לאתויי?
# מהי גזוזטרא? וכיצד משתמשים בה לשאיבת מים?
# האם משנה היכן עושה את המחיצות בגזוזטרא (מעליה או מתחתיה)?
# האם יכול לשפוך שופכין מן הבית אל הים דרך נקב הגזוזטרא?
# המפליג בספינה האם יכול למלאת מים מן הים?
# דופני הספינה מבחוץ גבוהים עשרה כיצד יעשה?
# באיזה אופן יכול לשפוך שופכין מן הספינה לים ללא דף וללא זיז?
# שתי ספינות זו אצל זו האם מותר לטלטל מזו לזו?
# היו דופני הספינה גבוהים עשרה טפחים מעל המים?
# .1 כיצד יש לעשות בית הכסא שעל פני המים?
# באיזה מקרה מותר בית הכסא הנ"ל ללא מחיצות?
# נשבר הדף בשבת?
# בית הכסא הבולט חוץ לחומת העיר וצואה נופלת לכרמלית?
# בית הכסא למעלה מעשרה?
# היה שם צואה מבעוד יום?
# בית הכסא העומד בין שני בתים מה דינו?
# .5 האם מותר להולכי ספינות לעשות צרכיהם על משוטיה?
# מים שאינם עמוקים עשרה טפחים מהו לשפוך להם או לשאוב מהם ע"י מחיצה תלויה?
# יבשו המים ובתחילה היו עמוקים?
# בית ועליה על גביו העומדת אצל הנהר ולכל אחת גזוזטרא בולטת מהו לדלות על ידה מן הנהר?
# תקנו בשותפות רק גזוזטרא אחת כדין?
# האם משנה מה הגובה שבין שתי הגזוזטרות?
# עשו בשתיהן בשותפות משל שניהם?
# מהי אמת המים שבחצר? ומה דינה?
# מהו התיקון המתיר למלאת מאמת המים שבחצר?
# היתה המחיצה כולה משוקעת במים?
# עשה המחיצה מקנים?
# באיזה מקרה יהא מותר למלאת מן האמה ללא צורך במחיצה?
# חצר שנפרצה ולשון ים עוברת לתוך החצר מהו למלאת ממנו?
# נפרצה החצר במלואה או יותר מעשרה?
# נפרצה החצר במלואה או יותר מעשרה ולא נשאר גדודים גבוהים עשרה?
# כמה מים צורך אדם בכל יום? ובאיזה שטח הם נבלעים?
# חצר שהיא פחותה מד' על ד' אמות וסמוכה לרה"ר האם מותר לשפוך לתוכה מים בשבת?
# כיצד יתקן את החצר שאין בה ד' על ד' אמות?
# מה המידות של גומא המחזקת סאתים?
# מדוע צריך לכסות הגומא שמחוץ לחצר?
# עשה גומא המחזקת סאתים כמה יכול לשפוך בה?
# גומא שאינה מחזקת סאתים האם מהני?
# חצר שהיא ד' על ד' אריך וקטין?
# האם חצר ואכסדרה מצטרפים לד' אמות?
# מתי חצר שהיא פחות מד' על ד' מותר לשפוך לתוכה כל שירצה ללא גומא?
# מהו ביב? ומה דינו?
# ביב העשוי מסילון של עץ?
# ביב העשוי כעין רצפה של אבנים?
# .4 מהי שיטת הרמב"ם וכיצד נקטינן?
# היו המים יוצאים לכרמלית?
# האם יש חלוק בדין הכרמלית לדעת הרמ"א?
# המים נשפכים מן הביב לחצר שאינה מעורבת ומשם לכרמלית?
# עיר מוקפת חומה ולא ערבו בה?
# צנור גבוה למעלה מעשרה המקלח לכרמלית?
# היקף שלא הוקף לדירה והוא יותר מסאתים או סאתים מה דינם?
# מהו שיעור סאתים?
# האם משנה מהי צורת הבית סאתים לדינא?
# במקום שאין זוכרים אם הקרפיפות נבנו קודם הבתים או אחר הבתים ולתשמיש דירה?
# קרפף שסמוך לביתו ולא פתח לו פתח לבית?
# מה נקרא מוקף לדירה?
# הקיף מקום וחשב בפירוש שיבנה בית באמצעו?
# מוקף שלא לשם דירה ורוצה שיהא מוקף לדירה?
# האם רשאי לפרוץ ולגדור כל אמה בפני עצמה?
# מי שקשה לו לפרוץ הכותל מה יעשה?
# מדוע בכותל שגבוה עשרים טפחים לא מהני תקנה זו?
# האם צריך להשאיר העפר שם לעולם?
# תל גבוה עשרה טפחים כיצד נידון?
# קרפף יותר מסאתים שנטע בו אילנות למעטו?
# החופר בור בקרפף הנ"ל כדי למעטו?
# בנה עמוד בתוך הקרפף הנ"ל כדי למעטו?
# בנה מחיצה במקביל למחיצה הראשונה כדי למעט הקרפף הנ"ל?
# בנה מחיצה כנ"ל והיא סמוכה למחיצה הראשונה בפחות מג' מתי יהא מותר?
# טח טיט על המחיצות הראשונות של הקרפף למעטו?
# האם ניתן להקל כאשר אין הטיט יכול לעמוד בפני עצמו רק עם הכותל?
# בנה מחיצות על המחיצות של הקרפף הראשונות להקיפו לדירה?
# נבלעו המחיצות הראשונות ונותרו העליונות השניות?
# תל יותר מסאתים שעשו מחיצות על שפתו לדירה?
# האם בעינן שיבנה ארבע מחיצות מסביב לתל?
# קרפף יותר מסאתים שהוקף לדירה ונטע נטיעות בכולו האם מתבטל?
# קרפף הנ"ל וזרע ברובו?
# קרפף הנ"ל וזרע במעוטו?
# מי שיש לו גנה בחצר מה דין החצר?
# מהו לטלטל מן החצר שהיא סאתים לבית?
# חצר שהיא יותר מסאתים וזרע גנה ברובה?
# חצר שהיא יותר מסאתים וזרע גנה במעוטה?
# חצר שהיא סאתים וזרע גנה במעוטה?
# עשו מחיצה בין החצר לזרעים?
# קרפף יותר מסאתים שהוקף לדירה ונכנסו בו מים?
# 16. פועל שקיבל עליו כל אונס ובא אונס דלא שכיח כלל?
# 17. שכר סוס לרכוב עליו למקום פלוני ונמלך לעבוד בו במקום זה בעבודה קשה יותר?
# 1. השוכר את הפועל להביא לו שליחות ממקום למקום, והלך ולא מצא שם מה שיביא?
# 2. האם משלם לו כפי שקצץ עמו או כפי שנשכר פועל לשליחות זו?
# 3. השוכר את הפועל להביא לו דבר כבד ממקום פלוני והלך לשם ולא מצא מה שיביא?
# 1. שכר פועל להביא תפוחים לחולה והלך והביא ומצאו שמת או שהבריא?
# 2. המזמין שרברב לתקן תיקון בצנרת וניסה לתקן ולא עלה בידו האם צריך לשלם לו?
# 3. קבלן שנאנס באמצע המלאכה?
# 1. השוכר את הפועל לעצמו ומסר לו עבודה השייכת לחבירו?
# 2. האם יכול לומר לפועל טול מה שעשית בשכרך?
# 3. שכרו בפירוש לעשות בשל חבירו ולא פירש מי ישלם השכר?
# 4. שכר את הפועל בשביל חבירו בכך וכך, וחבירו שמע ושתק, כמה ישלם?
# 5. אשה שכרה עובד ושמע בעלה ושתק?
# 6. אמר לחתנו העשיר תלמד עם בנך ואני אשלם לך?
# 1.השוכר את הפועל ללקט לו דבר של הפקר מהו שיאמר לו טול מה שעשית בשכרך?
# 2. אין לבעה"ב מעות רק מטלטלין האם חייב למוכרן מיד ולקיים מצות ביומו תתן שכרו?
# 3. האם יכול לתת לפועל דברי מאכל כתשלום השכירות?
# 4. האם יכול בעה"ב לשלם לעובד בהמחאה "צ"ק"?
# 5. האם המעביד צריך לטרוח ולהוליך השכר לעובד?
# 6. נתרצה הפועל לקבל ממה שמלקט בשכרו, וחזר בו?
# 7. האם בשכירות בתים וכלים רשאי לשלם בשוה כסף?
# 1. הבטיח שכר לחבירו עבור מניעת פעולה כגון שימנע לעסוק בעיסוק מסוים האם הוי שכירות?
# 2. שכר את הפועל לשמר לו דבר של הפקר האם יכול לומר לו טול מה שעשית בשכרך?
# 1. השוכר את הפועל ונלקח לעבודה אצל המלך בעל כרחו כמה משלם לו?
# 2. גבי בהמה מבואר בחו"מ סימן ש"י ס"א שאם נלקחה לעבודת המלך דנותן לו שכרו משלם, ומאי שנא הכא דלא?
# 3. האם צריך השוכר להמתין עד שהפועל יחזור מעבודת המלך?
# 4. מעביד שפשע והעמיס על הסבל יותר מכפי מנהג הסבלים, וניזוק העובד מכך?
# 5. אדם שלח שליח למקום שיש בו סכנה, ונהרג השליח בדרך?
# 6. עובד שתוך כדי עבודתו גרם נזק למעבידו בגרמא?
# 1. מי רשאי לאכול בשעת המלאכה מן התורה?
# 2. האם מנהג יכול לבטל דין אכילת פועל בשעת מלאכה?
# 3. מדוע מוזהר הפועל ואל כליך לא תתן הרי בכלל גזל הוא?
# 4. האם פועל העובד אצל נוכרי אוכל כמו אצל ישראל?
# 5. האם צריך שהפועל יעבוד בידיו וברגליו כדי שיהא רשאי לאכול מן התורה?
# 6. חסם בעה"ב את הפועל מלאכול?
# 7. התנה עם הפועל שלא יאכל?
# 1. באיזה דברים ומתי פועל אוכל מן התורה?
# 2. האם העודר בגפנים או מכסה שורשי האילנות או המנכש בבצלים ובשומים אוכלים מן התורה?
# 3. הבודל בתמרים ובגרוגרות האם אוכל?
# 4. פירות שפטורים ממעשר לדעת רוב הראשונים האם פועל אוכל בהם לעולם?
# 5. בצר ענבים לעשות מהם יין או זיתים לעשות מהם שמן מתי הוא גמר חיוב למעשר?
# 6. האם גם בשעורים אמרינן כמו בחיטים שאוכל מהם עד שיגמור מלאכתו להתחייב בחלה?
# 7. מהו גמר מלאכה לחלה?
# 8. הבודל בתמרים הרעים האם יכול לאכול מהם?
# 1. נפתחו חביותיו ונתפרסו עיגוליו ושכר פועל לעשות בהם?
# 2. מהו גמר המלאכה ביין ובתאנים מיובשות?
# 1. השומר במחובר בשעת גמר מלאכה האם אוכל מן התורה?
# 2. מתי פועל אוכל מהלכות מדינה אע"פ שמן התורה אינו אוכל?
# 3. האם משגיח כשרות דינו כשומר?ומפעיל קומביין לקצור תבואה?
# 4. מה פרוש הלכות מדינה?
# 1. האם רשאי הפועל לאכול יותר משכרו?
# 2. שכרו ללקוט קישות אחת האם רשאי לאוכלה?
# 3. האם רשאי הפועל לאכול ממה שנתן לכליו של בעה"ב?
# 1. פועל ששומר פירות אצל כמה מעבידים כיצד יאכל?
# 2. השומר אצל אדם אחד כמה ערימות פירות האם רשאי לאכול מאחת מהן?
# 1. פועל שנשכר לעשות בענבים ובתאנים מהו שיאכל בתאנים כשעושה בענבים?
# 2. מהו שימנע עצמו מלאכול עד שמגיע ליפות?
# 3. הבוצר ענבים כדי לדרוך בגת ממתי רשאי לשתות תירוש?
# 4. מתי יכול העושה בגפן זה לאכול מגפן אחרת?
# 1. האם רשאי פועל למנוע עצמו מלאכול בשעת הבציר כדי שיאכל אח"כ בהפסקות?
# 1.האם רשאי הפועל בשעה שאוכל מן הענבים לאכול פת או דבר אחר כדי שיאכל הרבה מן הענבים?
# 2. קצץ הפועל אם בעה"ב שיאכל ענבים עם פת או במלח?
# 1. האם רשאי הפועל למצוץ הענבים?
# 2. האם יש מקרה שרשאי לקלף?
# 1. האם רשאי הפועל לאכול אכילה גסה?
# 2. אכל לפני שהגיע למלאכה האם רשאי לאכול אכילה גסה?
# 1. האם יכול הפועל קודם אכילת הפירות לטבול פיתו בציר כדי שיאכל ענבים הרבה?
# 1. פועל שאמר לבעה"ב תן לאשתי ולבני מה שהיה מגיע לי לאכול?
# 2. התנה הפועל קודם העבודה שיתנו הפרות לאשתו ובניו?
# 3. הגיע הפרי ליד הפועל ועדיין לא אכל ממנו, ולקחו בעה"ב מידו וקידש בו אשה?
# 4. פועל המודר מבעה"ב הנאת מאכל האם רשאי לאכול בעת הבציר?
# 5. נזיר שהיה עושה בענבים ואמר תנו לאשתי ובני?
# 1.פועל שהיה עושה עם אשתו ובניו והתנה עם בעה"ב שלא יאכלו ממה שהם עושים?
# 2. האם יכול להתנות שבהמתו לא תאכל במלאכתה?
# 1. פועל האוכל בשעה שאין לו רשות לאכול?
# 1. האם רשאי לעשות מלאכה בלילה ולהשכיר עצמו ביום?
# 1. אמר לגוי חסום פרתי ודוש בה?
# 2. רבץ ארי מבחוץ ומחמת זה אינה אוכלת?
# 3. האם צריך לשלם בכל המקרים האלו?
# 1. באיזה מקרים אינו עובר איסור אע"פ שמונעה ממאכל?
# 2. האם צריך לתלות איזה מאכל בצוארה במקרים האלו משום מראית העין?
# 1. המעביר פרות ודרך הילוכן על תבואתו דשות במקרה האם יש איסור לחוסמם?
# 2. הדש בבהמתו בשעורים שנתחייבו במעשר האם יש בזה איסור חסימה?
# 3. לא תלה בצוארה משום מראית העין האם יכול לתבוע ממון?
# 1. האם רשאי בעל הפרה להרעיב את הבהמה כדי שתאכל הרבה?
# 2. האם רשאי השוכר להאכילה פקיעי אמיר כדי שתאכל פחות מהדיש?
# 1. האם על כל פועל קאי המצוה של ביומו תתן שכרו?
# 2. מה הטעם דהקפידה התורה לתת שכר הפועל בזמנו?
# 3.מי שדעתו לשלם לפועל ואיחר הזמן?
# 4. האם גם בשכיר גוי יש מצוה לפורעו בזמנו?
# 5.האם בפועל קטן יש מצוה לפורעו בזמנו?
# 6.האם גם בבהמה ובכלים ובקרקע יש מצוה לפרוע בזמנו?
# 7. האם בחשבונות חשמל מים גז וטלפון יש משום ביומו תתן שכרו?
# 8.האם באברכי כולל יש משום ביומו תתן שכרו?
# 1. מהו כובש שכר שכיר, ומה דינו?
# 2. האם יש איסור הלנת שכר על חלק מהשכר?
# 3. האם יש איסור הלנת שכר על פחות מפרוטה?
# 4. מהו עונשם של עושקי שכר שכיר?
# 5. מה העצה שלא יכשל אדם בעושק שכר שכיר?
# 6. האם מותר למסור דינו לשמים לבעה"ב המעכב שכרו?
# 7. למה יזכה בשבת המשלם שכר שכיר בזמנו?
# 1. מהו זמנו של שכיר יום ושל שכיר לילה?
# 2. שכר פועל לעבוד עד הצהרים, והמשיך לעבוד עד הלילה מתי צריך לשלם לו?
# 3. הקדים המעביד לשלם שכר הפועל קודם סיום העבודה האם מקיים בזה ביומו תתן שכרו?
# 4. שכיר שכלתה שכירותו בכניסת השבת ונדחה מלפרוע מחמת השבת – מה דינו?
# 5.שכיר שגמר מלאכתו בערב שבת ובעה"ב קיבל שבת מבעוד יום – כיצד יעשה?
# 6. עובד שחייב נזק לבעה"ב עבור נזק שעשה לו, האם יכול לעכב שכרו עבור החוב?
# 1. מהו שכיר שעות ודינו?
# 2. בעה"ב נמצא בחו"ל והפועל בא"י, ובחו"ל עדיין יום הוא?
# 3. סיים עבודתו קודם עלות השחר?
# 4. נשכר לכל היום שזמנו לגבות כל הלילה, וחזר בו הפועל באמצע היום?
# 1. שכיר שבועי או חודשי או שנתי עד מתי גובה שכרו?
# 2. אצל פועל גוי לסוברים שיש מצוה לפורעו כיצד הולכים אחר היום והלילה?
# 3. מתי זמן הפרעון בשכירות כלים ובתים?
# 4. פועל השכור לחודש ויש שני ימים ראש חודש – לאיזה חודש יש לשייך אותם?
# 1. נתן טליתו לאומן לתקנה בקבלנות וגמרה ואמר לו בא וטול ושלם לי?
# 2. אין לבעה"ב לשלם לאומן וגם להוצאות שבת מה יעשה?
# 47. בעה"ב מסופק אם שילם לפועל מה יעשה?
# 48. גמר לעבוד רגע לפני השקיעה ולא הספיק בעה"ב לשלם לו האם עובר בבל תלין?
# 49. נשבע בעה"ב שישלם לפועל ביום שיגמור העבודה והפועל לא תבעו מה הדין?
# 50.באו עדים לפני בעה"ב והעידו שהפועל אינו יודע שצריך לתבוע האם יעבור על בל תלין?
# 51. האם בעלי מניות עוברים על בל תלין על עסקי החברה?
# 52. אחד היה ערב לשכר הפועלים האם בעה"ב עובר על בל תלין?
# 53. כשאין לבעה"ב שקלים האם מחויב לשלם בדולרים?
# 54. פועל שתבע שכרו ואין לבעה"ב כסף ואין בדעתו לשלם גם כשיהיה לו כסף?

# %%
import pickle
# שמירה ל-pickle
with open("embeddings.pkl", "wb") as f:
    pickle.dump(embeddings2, f)

print("ה-embeddings נשמרו בהצלחה!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9274e9ab35d7> in <cell line: 3>()
#       2 # שמירה ל-pickle
#       3 with open("embeddings.pkl", "wb") as f:
# ----> 4     pickle.dump(embeddings2, f)
#       5
#       6 print("ה-embeddings נשמרו בהצלחה!")
#
# NameError: name 'embeddings2' is not defined

# %%
import pickle
import numpy as np

# טעינת embeddings מקובץ pickle
with open("embeddings.pkl", "rb") as f:
    embeddings2 = pickle.load(f)

print("ה-embeddings נטענו בהצלחה!")
print(embeddings2)
# Out:
# ה-embeddings נטענו בהצלחה!
# [[ 2.812   0.0607 -1.676  ... -1.807   2.26   -0.284 ]
#  [ 2.812   0.0607 -1.676  ... -1.807   2.26   -0.284 ]
#  [ 2.812   0.0607 -1.676  ... -1.807   2.26   -0.284 ]
#  ...
#  [ 2.812   0.0607 -1.676  ... -1.807   2.26   -0.284 ]
#  [ 2.812   0.0607 -1.676  ... -1.807   2.26   -0.284 ]
#  [ 2.812   0.0607 -1.676  ... -1.807   2.26   -0.284 ]]

# %%
# הצגת כל הקבצים בתיקיית /content
# !ls /content

# הורדת קובץ למחשב
from google.colab import files
files.download('embeddings.pkl')
# Out:
# embeddings.pkl	sample_data

# %%
# בניית אינדקס FAISS
dimension = embeddings2.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings)

# פונקציה למציאת השאלות הקרובות ביותר
def find_nearest_questions(query, k=5):
    query_embedding = get_embedding(query).reshape(1, -1)
    distances, indices = index.search(query_embedding, k)
    nearest_questions = [questions[idx] for idx in indices[0]]
    return nearest_questions
print("cancel")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-5d54da5adfff> in <cell line: 3>()
#       1 # בניית אינדקס FAISS
#       2 dimension = embeddings2.shape[1]
# ----> 3 index = faiss.IndexFlatL2(dimension)
#       4 index.add(embeddings)
#       5
#
# NameError: name 'faiss' is not defined

# %%
# בניית אינדקס FAISS
dimension2 = embeddings2.shape[1]
index2 = faiss.IndexFlatL2(dimension2)
index2.add(embeddings)

# פונקציה למציאת השאלות הקרובות ביותר
def find_nearest_questions2(query, k=5):
    query_embedding = get_embedding2(query).reshape(1, -1)
    distances, indices = index2.search(query_embedding, k)
    nearest_questions = [questions[idx] for idx in indices[0]]
    return nearest_questions

# %%
# שאלה לדוגמה
query = "האם נשים חיבות בתפילה"

# מציאת השאלות הקרובות ביותר
nearest_questions = find_nearest_questions(query, k=5)
print("השאלות הקרובות ביותר לשאלה שלך הן:")
for q in nearest_questions:
    print(q)

# %%
# שאלה לדוגמה
query = "האם נשים חיבות בתפילה"

# מציאת השאלות הקרובות ביותר
nearest_questions = find_nearest_questions2(query, k=5)
print("השאלות הקרובות ביותר לשאלה שלך הן:")
for q in nearest_questions:
    print(q)

# %%
import json
import torch
import faiss
import numpy as np
from transformers import AutoTokenizer, BertModel

# הגדרת המודל והטוקנייזר של heBERT
model_name = "avichr/heBERT"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)

# פונקציה ליצירת embeddings
def embeddingVectors(text):
    encoding = tokenizer.batch_encode_plus(
        text,  # List of input texts
        padding=True,  # Pad to the maximum sequence length
        truncation=True,  # Truncate to the maximum sequence length if necessary
        return_tensors='pt',  # Return PyTorch tensors
        add_special_tokens=True  # Add special tokens CLS and SEP
    )
    input_ids = encoding['input_ids']  # Token IDs
    attention_mask = encoding['attention_mask']  # Attention mask

    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
        word_embeddings = outputs.last_hidden_state  # (batch_size, sequence_length, embedding_dim)
        # החזרת ה-embedding של ה-CLS token
        sentence_embedding = word_embeddings[:, 0, :]  # בחירת האיבר הראשון בכל רצף (CLS token)
    return sentence_embedding  # This contains the embeddings

# קריאת הקובץ JSON
with open('/content/sample_data/פרי גני שוע.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# שליפת כל השאלות מהקובץ
questions = []
for book in data['contain'].values():
    for chapter in book.values():
        for verse in chapter.values():
            for qa in verse:
                questions.append(qa['question'])

# המרת כל השאלות ל-embeddings
embeddings = embeddingVectors(questions).numpy()

# בניית אינדקס FAISS
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings)

# פונקציה למציאת השאלות הקרובות ביותר
def find_nearest_questions(query, k=5):
    query_embedding = embeddingVectors([query]).numpy()
    distances, indices = index.search(query_embedding, k)
    nearest_questions = [questions[idx] for idx in indices[0]]
    return nearest_questions

# פונקציה לרנקר (הדוגמה היא פשוטה. ניתן לשפר בהתאם לצורך)
def rerank_documents1(query, documents, top_n=5):
    # המרת השאלה ל-embedding
    query_embedding = embeddingVectors([query]).numpy()

    # המרת המסמכים ל-embeddings
    doc_embeddings = embeddingVectors(documents).numpy()

    # חישוב המרחקים
    distances = np.linalg.norm(doc_embeddings - query_embedding, axis=1)

    # מציאת האינדקסים של המסמכים הקרובים ביותר
    nearest_indices = distances.argsort()[:top_n]

    # החזרת המסמכים המסודרים לפי הקרבה
    reranked_documents = [documents[idx] for idx in nearest_indices]
    return reranked_documents

def rerank_documents(query, docs, top_n):
    results = co.rerank(model="rerank-multilingual-v3.0", query=query, documents=docs, top_n=top_n, return_documents=True)
    reranked_docs = [res.document.text for res in results.results]
    return reranked_docs

# שאלה לדוגמה
query = "האם נשים חיבות בתפילה"

# מציאת השאלות הקרובות ביותר
nearest_questions = find_nearest_questions(query, k=10)

# רנקר על התוצאות הקרובות ביותר
reranked_questions = rerank_documents(query, nearest_questions, top_n=5)

print("השאלות הקרובות ביותר לשאלה שלך הן:")
for q in reranked_questions:
    print(q)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import json
import torch
import faiss
import numpy as np
from transformers import AutoTokenizer, BertModel
import cohere

# הגדרת המודל והטוקנייזר של heBERT
model_name = "avichr/heBERT"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)

# פונקציה ליצירת embeddings
def embeddingVectors(text):
    encoding = tokenizer.batch_encode_plus(
        text,  # List of input texts
        padding=True,  # Pad to the maximum sequence length
        truncation=True,  # Truncate to the maximum sequence length if necessary
        return_tensors='pt',  # Return PyTorch tensors
        add_special_tokens=True  # Add special tokens CLS and SEP
    )
    input_ids = encoding['input_ids']  # Token IDs
    attention_mask = encoding['attention_mask']  # Attention mask

    with torch.no_grad():
        outputs = model(input_ids, attention_mask=attention_mask)
        word_embeddings = outputs.last_hidden_state  # (batch_size, sequence_length, embedding_dim)
        # החזרת ה-embedding של ה-CLS token
        sentence_embedding = word_embeddings[:, 0, :]  # בחירת האיבר הראשון בכל רצף (CLS token)
    return sentence_embedding  # This contains the embeddings

# קריאת הקובץ JSON
with open('/content/sample_data/פרי גני שוע.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# שליפת כל השאלות מהקובץ
questions = []
for book in data['contain'].values():
    for chapter in book.values():
        for verse in chapter.values():
            for qa in verse:
                questions.append(qa['question'])

# המרת כל השאלות ל-embeddings
embeddings = embeddingVectors(questions).cpu().numpy()

# בניית אינדקס FAISS
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings)

# פונקציה למציאת השאלות הקרובות ביותר
def find_nearest_questions(query, k=20):
    query_embedding = embeddingVectors([query]).cpu().numpy()
    distances, indices = index.search(query_embedding, k)
    nearest_questions = [questions[idx] for idx in indices[0]]
    return nearest_questions

# %%
# הגדרת מפתח ה-API של Co:here

co = cohere.Client('IEo7xZnWi8cPD7jzR2dpsw3cvdGjchG6RCKPko05')
# פונקציה לרנקר
def rerank_documents(query, docs, top_n):
    results = co.rerank(model="rerank-multilingual-v3.0", query=query, documents=docs, top_n=top_n, return_documents=True)
    reranked_docs = [res.document.text for res in results.results]
    return reranked_docs

# שאלה לדוגמה
query = "האם נשים חיבות בתפילה"

# מציאת השאלות הקרובות ביותר
nearest_questions = find_nearest_questions(query, k=20)

# רנקר על התוצאות הקרובות ביותר
reranked_questions = rerank_documents(query, nearest_questions, top_n=5)

print("השאלות הקרובות ביותר לשאלה שלך הן:")
for q in reranked_questions:
    print(q)

# %%
# import cohere
# import faiss
# import numpy as np
# from langchain.embeddings import BedrockEmbeddings  # וודא שהחבילה מותקנת
# from langchain.embeddings.openai import OpenAIEmbeddings  # שימוש באפשרות אחרת אם BedrockEmbeddings לא עובד

# # הגדרת המפתח של Coherence
# COHERE_API_KEY = 'YOUR_COHERE_API_KEY'
# co = cohere.Client(COHERE_API_KEY)

# # רשימת השאלות
# questions = [
#     "מה היא מצוות תפילין?",
#     "כיצד יש להתפלל במניין?",
#     "מהי מצוות שמירת השבת?",
#     "כיצד יש לקיים את מצוות נטילת לולב?",
#     "מה הם דיני כשרות?"
# ]

# # המרת השאלות ל-embeddings
# def get_embeddings(questions):
#     response = co.embed(texts=questions)
#     embeddings = response.embeddings
#     return np.array(embeddings)

# embeddings = get_embeddings(questions)

# # בניית אינדקס FAISS
# dimension = embeddings.shape[1]
# index = faiss.IndexFlatL2(dimension)
# index.add(embeddings)

# # פונקציה למציאת השאלות הקרובות ביותר
# def find_nearest_questions(query, k=5):
#     query_embedding = get_embeddings([query])[0].reshape(1, -1)
#     distances, indices = index.search(query_embedding, k)
#     nearest_questions = [questions[idx] for idx in indices[0]]
#     return nearest_questions

# # שאלה לדוגמה
# query = "מה דיני תפילה במניין?"

# # מציאת השאלות הקרובות ביותר
# nearest_questions = find_nearest_questions(query, k=5)
# print("השאלות הקרובות ביותר לשאלה שלך הן:")
# for q in nearest_questions:
#     print(q)
